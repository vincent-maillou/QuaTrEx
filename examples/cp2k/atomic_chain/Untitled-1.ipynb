# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse

# %%
T = np.load("/home/mdossena/quatrex/examples/cp2k/atomic_chain/outputs/transmission_l->r.npy")

# %%
plt.plot(T)

# %%
plt.plot(dosL)

# %%
plt.plot(dosR)
