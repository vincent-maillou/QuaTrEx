# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse

# %%
T = np.load("/home/mdossena/quatrex/examples/cp2k/atomic_chain/outputs/transmission.npy")
dos = np.load("/home/mdossena/quatrex/examples/cp2k/atomic_chain/outputs/dos.npy")

# %%
plt.plot(T)
