# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse

# %%
T_b_qua = np.load("/home/mdossena/quatrex/examples/Effective Mass/InGaAs - 4 contacts/outputs/transmission_slabs_x_l.npy")
T_b_QT = np.loadtxt("/usr/scratch2/tortin17/mdossena/QTsolver_DEVICE/U_TE_0_0.dat")

plt.plot(T_b_qua[0,:],'xr',label='QuaTRex')
plt.plot(T_b_QT[0,:],'-b',label='QTsolver')
plt.legend()

# %%
plt.plot(T_b_qua[130,:],'xr',label='QuaTRex')
plt.plot(T_b_QT[130,:],'b',label='QTsolver')
plt.legend()

# %%
T_b_qua = np.load("/home/mdossena/quatrex/examples/Effective Mass/InGaAs - 4 contacts/outputs/transmission_slabs_x_r.npy")
T_b_QT = np.loadtxt("/usr/scratch2/tortin17/mdossena/QTsolver_DEVICE/U_TE_0_1.dat")

plt.plot(T_b_qua[0,:],'xr',label='QuaTRex')
plt.plot(T_b_QT[0,:],'-b',label='QTsolver')
plt.legend()

# %%
plt.plot(T_b_qua[130,:],'-xr',label='QuaTRex')
plt.plot(T_b_QT[130,:],'b',label='QTsolver')
plt.legend()

# %%
T_b_qua = np.load("/home/mdossena/quatrex/examples/Effective Mass/InGaAs - 4 contacts/outputs/transmission_slabs_x_t.npy")
T_b_QT = np.loadtxt("/usr/scratch2/tortin17/mdossena/QTsolver_DEVICE/U_TE_0_2.dat")

plt.plot(T_b_qua[0,:],'xr',label='QuaTRex')
plt.plot(T_b_QT[0,:],'-b',label='QTsolver')
plt.legend()

# %%
T_b_qua = np.load("/home/mdossena/quatrex/examples/Effective Mass/InGaAs - 4 contacts/outputs/transmission_slabs_x_t.npy")
T_b_QT = np.loadtxt("/usr/scratch2/tortin17/mdossena/QTsolver_DEVICE/U_TE_0_2.dat")

plt.plot(T_b_qua[130,:],'-xr',label='QuaTRex')
plt.plot(T_b_QT[130,:],'b',label='QTsolver')
plt.legend()

# %%
T_b_qua = np.load("/home/mdossena/quatrex/examples/Effective Mass/InGaAs - 4 contacts/outputs/transmission_slabs_x_b.npy")
T_b_QT = np.loadtxt("/usr/scratch2/tortin17/mdossena/QTsolver_DEVICE/U_TE_0_3.dat")

plt.plot(T_b_qua[0,:],'xr',label='QuaTRex')
plt.plot(T_b_QT[0,:],'-b',label='QTsolver')
plt.legend()

# %%
plt.plot(T_b_qua[130,:],'-xr',label='QuaTRex')
plt.plot(T_b_QT[130,:],'b',label='QTsolver')
plt.legend()

# %%
D_b_qua = np.load("/home/mdossena/quatrex/examples/Effective Mass/InGaAs - 4 contacts/outputs/dos_l.npy")
D_b_QT = np.loadtxt("/usr/scratch2/tortin17/mdossena/QTsolver_DEVICE/U_ZE_0_0.dat")

plt.plot(D_b_qua[0,:],'xr',label='QuaTRex')
plt.plot(D_b_QT[0,:],'-b',label='QTsolver')
plt.legend()

# %%
plt.plot(D_b_qua[130,:],'-xr',label='QuaTRex')
plt.plot(D_b_QT[130,:],'b',label='QTsolver')
plt.legend()

# %%
D_b_qua = np.load("/home/mdossena/quatrex/examples/Effective Mass/InGaAs - 4 contacts/outputs/dos_r.npy")
D_b_QT = np.loadtxt("/usr/scratch2/tortin17/mdossena/QTsolver_DEVICE/U_ZE_0_1.dat")

plt.plot(D_b_qua[0,:],'xr',label='QuaTRex')
plt.plot(D_b_QT[0,:],'-b',label='QTsolver')
plt.legend()

# %%
plt.plot(D_b_qua[130,:],'-xr',label='QuaTRex')
plt.plot(D_b_QT[130,:],'b',label='QTsolver')
plt.legend()

# %%
D_b_qua = np.load("/home/mdossena/quatrex/examples/Effective Mass/InGaAs - 4 contacts/outputs/dos_t.npy")
D_b_QT = np.loadtxt("/usr/scratch2/tortin17/mdossena/QTsolver_DEVICE/U_ZE_0_2.dat")

plt.plot(D_b_qua[0,:],'xr',label='QuaTRex')
plt.plot(D_b_QT[0,:],'-b',label='QTsolver')
plt.legend()

# %%
plt.plot(D_b_qua[130,:],'-xr',label='QuaTRex')
plt.plot(D_b_QT[130,:],'b',label='QTsolver')
plt.legend()

# %%
D_b_qua = np.load("/home/mdossena/quatrex/examples/Effective Mass/InGaAs - 4 contacts/outputs/dos_b.npy")
D_b_QT = np.loadtxt("/usr/scratch2/tortin17/mdossena/QTsolver_DEVICE/U_ZE_0_3.dat")

plt.plot(D_b_qua[0,:],'xr',label='QuaTRex')
plt.plot(D_b_QT[0,:],'-b',label='QTsolver')
plt.legend()

# %%
plt.plot(D_b_qua[130,:],'-xr',label='QuaTRex')
plt.plot(D_b_QT[130,:],'b',label='QTsolver')
plt.legend()
